# %%
! pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.13)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 22.5 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 12.2 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 16.0 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.3.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
# Import necessary libraries
import math
import logging
from sentence_transformers import LoggingHandler
from torch.utils.data import DataLoader
from sentence_transformers.cross_encoder import CrossEncoder
from sentence_transformers.readers import InputExample
from sentence_transformers.cross_encoder.evaluation import CEBinaryClassificationEvaluator, CECorrelationEvaluator
from datasets import load_dataset
from datetime import datetime

# Configure logging settings
logging.basicConfig(
    format="%(asctime)s - %(message)s", datefmt="%Y-%m-%d %H:%M:%S", level=logging.INFO, handlers=[LoggingHandler()]
)
logger = logging.getLogger(__name__)

# %%
# Authenticate with Hugging Face Hub
from huggingface_hub import login
login('hf_your_token')

# Load training and test datasets from Hugging Face Datasets
df_train = load_dataset("your_username/your_dataset_name", split="train")
df_test = load_dataset("your_username/your_dataset_name", split="test")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/969 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/49.0M [00:00<?, ?B/s]
# test-00000-of-00001.parquet:   0%|          | 0.00/9.83M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/241957 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/39359 [00:00<?, ? examples/s]

# %%
# Convert dataset into a list of InputExample objects for model training
def convert_dataset(dataset):
    dataset_samples=[]
    for df in dataset:
        inp_example = InputExample(
            texts=[df['text1'], df['text2']],
            label=df['label']
            )
        dataset_samples.append(inp_example)
    return dataset_samples

# %%
# Convert datasets into the required format
train_samples = convert_dataset(df_train)
test_samples = convert_dataset(df_test)

# Select appropriate evaluator based on the type of labels in the dataset:
# - If labels are purely binary (0 or 1), use `CEBinaryClassificationEvaluator`.
# - If labels contain continuous values (e.g., STS scores), use `CECorrelationEvaluator`.
# evaluator = CEBinaryClassificationEvaluator.from_input_examples(test_samples, name="CE-binary-dev")
evaluator = CECorrelationEvaluator.from_input_examples(test_samples, name='CE-Corr-dev')
train_batch_size = 16
num_epochs = 4

# Training configuration
model_save_path = f'output/training_crossencoder_{datetime.now().strftime("%Y-%m-%d_%H-%M-%S")}'

# %%
# We wrap train_samples (which is a List[InputExample]) into a pytorch DataLoader
train_dataloader = DataLoader(train_samples, shuffle=True, batch_size=train_batch_size)

# Define the model base; can be changed based on requirements and experiments.
# Here, we use `distilroberta-base`, which outputs a similarity score between 0 and 1.
model_base = "distilroberta-base"
model = CrossEncoder(model_base, num_labels=1)
# Out:
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at distilroberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
from tqdm.autonotebook import tqdm, trange

# Custom callback function to log training loss and evaluation scores
class LossAndScoreCallback:
    def __call__(self, score, epoch, steps):
        print(f'Epoch {epoch}, Step {steps}, score: {score}')

# Configure the number of warm-up steps (10% of total training steps)
warmup_steps = math.ceil(len(train_dataloader) * num_epochs * 0.1)  # 10% of train data for warm-up
logger.info("Warmup-steps: {}".format(warmup_steps))

# Initialize callback
callback = LossAndScoreCallback()

# Train the model
model.fit(
    train_dataloader=train_dataloader,
    evaluator=evaluator,
    epochs=num_epochs,
    evaluation_steps=5000,
    warmup_steps=warmup_steps,
    output_path=model_save_path,
    save_best_model=True,
    callback=callback
)
# Out:
# Epoch:   0%|          | 0/4 [00:00<?, ?it/s]
# Iteration:   0%|          | 0/15123 [00:00<?, ?it/s]

# %%
# Evaluate the model on the test set and save the results
evaluator(model, output_path="./")

# %%
# Function to evaluate a single data pair using the trained model
# Example: Using the STS-B dataset
# If working with other QA datasets like PIAF or SQuAD-French,
# please refer to reranker-prepare-dataset.ipynb for dataset conversion.

def convert_dataset_stsd(dataset):
    """
    Converts the STS-D dataset into a structured format.

    Args:
        dataset (Dataset): The input dataset containing sentence pairs and similarity scores.

    Returns:
        List[dict]: A list of structured samples with normalized similarity scores.
    """
    dataset_samples=[]
    for df in dataset:
        score = float(df['similarity_score'])/5.0  # Normalize score to range 0 ... 1
        inp_example = InputExample(
            texts=[df['sentence1'], df['sentence2']],
            label=score
          )
        dataset_samples.append(inp_example)
    return dataset_samples

# Load STS-B dataset in French for evaluation
df_dev = load_dataset("stsb_multi_mt", name="fr", split="dev")
df_test = load_dataset("stsb_multi_mt", name="fr", split="test")

# Convert the dev set for evaluation
dev_samples = convert_dataset_stsd(df_dev)

# Evaluate the dev set using CECorrelationEvaluator (for continuous similarity scores)
val_evaluator = CECorrelationEvaluator.from_input_examples(dev_samples, name='sts-dev')
val_evaluator(model, output_path="./")
# Out:
# 0.9187334632822911

# %%
dev_samples
# Out:
# [{'texts': ['Un homme avec un casque de sécurité est en train de danser.',
#    'Un homme portant un casque de sécurité est en train de danser.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un jeune enfant monte à cheval.', 'Un enfant monte à cheval.'],
#   'label': 0.95,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme donne une souris à un serpent.',
#    "L'homme donne une souris au serpent."],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme joue de la guitare.', 'Un homme joue de la guitare.'],
#   'label': 0.48000001907348633,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme joue de la flûte.', 'Un homme joue de la flûte.'],
#   'label': 0.55,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de couper un oignon.',
#    'Un homme coupe des oignons.'],
#   'label': 0.5230000019073486,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme efface un tableau à craie.',
#    "L'homme efface le tableau noir."],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme porte un garçon.', 'Une femme porte son bébé.'],
#   'label': 0.4665999889373779,
#   'source': 'stsd-fr'},
#  {'texts': ['Trois hommes jouent de la guitare.',
#    'Trois hommes sont sur scène et jouent de la guitare.'],
#   'label': 0.75,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme épluche une pomme de terre.',
#    'Une femme épluche une pomme de terre.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Les gens jouent au cricket.', 'Les hommes jouent au cricket.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.', 'Un homme joue de la flûte.'],
#   'label': 0.31659998893737795,
#   'source': 'stsd-fr'},
#  {'texts': ["Le couguar poursuit l'ours.", 'Un couguar poursuit un ours.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme a coupé un arbre avec une hache.",
#    'Un homme abat un arbre avec une hache.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme joue de la guitare.", 'Un homme joue de la guitare.'],
#   'label': 0.9817999839782715,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de trouver quelque chose.',
#    'Une femme est en train de découper quelque chose.'],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ['La fille a chanté dans un micro.',
#    'La dame a chanté dans le micro.'],
#   'label': 0.48000001907348633,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de grimper à une corde.',
#    'Un homme grimpe sur une corde.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Les chatons mangent de la nourriture.',
#    'Les chatons mangent dans les plats.'],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme parle.', 'Un homme est en train de cracher.'],
#   'label': 0.1271999955177307,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme fait cuire des œufs.',
#    'Une femme est en train de cuisiner quelque chose.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.', 'Un homme joue de la trompette.'],
#   'label': 0.3427999973297119,
#   'source': 'stsd-fr'},
#  {'texts': ['Un animal est en train de mâchouiller quelque chose.',
#    'Un animal mâche un porte-clés.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la flûte.', 'Un homme joue de la guitare.'],
#   'label': 0.43340001106262205,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue au football.', 'Un homme joue de la flûte.'],
#   'label': 0.2,
#   'source': 'stsd-fr'},
#  {'texts': ['Une fille monte à cheval.', 'Une fille fait du vélo.'],
#   'label': 0.38340001106262206,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme soulève des poids dans un garage.',
#    'Un homme soulève des poids.'],
#   'label': 0.85,
#   'source': 'stsd-fr'},
#  {'texts': ["Un animal mord le doigt d'une personne.",
#    "Un loris lent mord le doigt d'une personne."],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de lire.', 'Une femme pétrit la pâte.'],
#   'label': 0.2,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme pleure.', 'Une femme est en train de danser.'],
#   'label': 0.12000000476837158,
#   'source': 'stsd-fr'},
#  {'texts': ['La dame a cassé un œuf dans un bol.',
#    "L'homme est en train de casser des œufs dans un bol."],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Un groupe se produit sur une scène.',
#    'Un groupe se produit sur scène.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Les éléphants marchent sur un sentier.',
#    "Un troupeau d'éléphants se promène sur un sentier."],
#   'label': 0.9199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.', 'Un homme joue de la guitare.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme assis par terre joue de la guitare.',
#    'Un homme assis par terre dans une pièce est en train de gratter une guitare.'],
#   'label': 0.9600000381469727,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chiot joue avec un récipient en plastique.',
#    'Le chien joue avec un récipient en plastique.'],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue du violon.', 'Un homme joue du violon.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue du piano.', 'Un homme joue du piano.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme mange de la nourriture.',
#    'Un homme est en train de manger quelque chose.'],
#   'label': 0.8399999618530274,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue au basket-ball.', 'Un homme joue du piano.'],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ['Un bambin marche dans un couloir.',
#    'Une petite fille marche dans un couloir.'],
#   'label': 0.7199999809265136,
#   'source': 'stsd-fr'},
#  {'texts': ["Un avion est en train d'atterrir.",
#    "Un avion animé est en train d'atterrir."],
#   'label': 0.5599999904632569,
#   'source': 'stsd-fr'},
#  {'texts': ['Un panda est en train de grimper.',
#    'Un homme est en train de grimper à une corde.'],
#   'label': 0.3200000047683716,
#   'source': 'stsd-fr'},
#  {'texts': ['Les enfants dansent sur scène.',
#    'Certaines personnes dansent sur scène.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.', 'Un homme joue du piano.'],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de découper une viande.',
#    'Une femme chante sur scène.'],
#   'label': 0.05,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme prend une photo.', 'Un homme joue de la guitare.'],
#   'label': 0.05,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme est à cheval.", 'Une femme utilise une houe.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de percer un trou dans une planche.',
#    "Quelqu'un est en train de percer un trou dans un morceau de bois."],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme installe un silencieux sur un pistolet.',
#    'Un homme ajoute un silencieux à une arme.'],
#   'label': 0.9,
#   'source': 'stsd-fr'},
#  {'texts': ['Deux petites filles parlent au téléphone.',
#    'Une petite fille marche dans la rue.'],
#   'label': 0.1,
#   'source': 'stsd-fr'},
#  {'texts': ["Quelqu'un remue le chili dans une bouilloire.",
#    "Quelqu'un remue un pot de chili avec une cuillère."],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['La femme est en train de casser des œufs dans un bol.',
#    'La dame a cassé des œufs crus dans un bol.'],
#   'label': 0.9600000381469727,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme met de la farine sur un morceau de viande.',
#    'Une femme met de la farine sur de la viande.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme parle au téléphone.', 'Un homme chante pour une femme.'],
#   'label': 0.05,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue sur un clavier électronique.',
#    'Un homme joue de la flûte.'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.',
#    'Un homme est en train de manger une banane.'],
#   'label': 0.12000000476837158,
#   'source': 'stsd-fr'},
#  {'texts': ["Un homme saute dans l'eau.",
#    'Un homme est en train de couper du papier.'],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.', "Un type joue d'un instrument."],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Un jeune homme joue du piano.',
#    'Une femme est en train de peler une crevette.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme mélange des ingrédients.',
#    'Une femme mélange de la nourriture dans un bol.'],
#   'label': 0.7,
#   'source': 'stsd-fr'},
#  {'texts': ["Quelqu'un déchiquette les feuilles de chou avec un couteau.",
#    "Quelqu'un coupe des feuilles de chou."],
#   'label': 0.9,
#   'source': 'stsd-fr'},
#  {'texts': ['Un lori lent se promène.', 'Un animal se promène.'],
#   'label': 0.5599999904632569,
#   'source': 'stsd-fr'},
#  {'texts': ["Un petit garçon passe l'aspirateur sur le sol.",
#    "Un garçon passe l'aspirateur."],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["Une femme applique de l'eye-liner sur sa paupière à l'aide d'un crayon pour les yeux.",
#    'Une femme applique des cosmétiques sur sa paupière.'],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme fait un lit.', 'Une femme joue de la guitare.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue du clavier.', 'Une personne joue au clavier.'],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ['Un lapin joue avec un petit lapin.',
#    'Un lapin joue avec un lapin en peluche.'],
#   'label': 0.85,
#   'source': 'stsd-fr'},
#  {'texts': ['Un avion roule sur une route.',
#    "Un avion se déplace le long d'une piste."],
#   'label': 0.5624000072479248,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme tire sur un homme.',
#    'Un homme avec un pistolet tire sur un autre homme.'],
#   'label': 0.85,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.',
#    "L'homme chantait et jouait de la guitare."],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Un gars joue au piratage informatique',
#    'Un homme joue au clavier.'],
#   'label': 0.2,
#   'source': 'stsd-fr'},
#  {'texts': ["Un homme brise le ciment sur la poitrine d'un autre homme.",
#    'Un homme casse des parpaings sur un autre homme.'],
#   'label': 0.75,
#   'source': 'stsd-fr'},
#  {'texts': ["Un homme parle avec d'autres femmes sur la plage.",
#    'Un homme marche dans la rue.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['La femme est en train de couper des oignons en dés.',
#    'Une femme danse dans une gare.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chef cuisinier prépare un repas.',
#    'Un chef a préparé un repas.'],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme a parlé à une fille par le biais de la caméra Internet.",
#    "Un adolescent parle à une fille par le biais d'une webcam."],
#   'label': 0.5599999904632569,
#   'source': 'stsd-fr'},
#  {'texts': ['Une tortue marche sur le sol.',
#    "Une grande tortue rampe dans l'herbe."],
#   'label': 0.75,
#   'source': 'stsd-fr'},
#  {'texts': ['La dame a cassé un œuf pour le mixer.',
#    'La dame a coupé la viande en tranches.'],
#   'label': 0.23080000877380372,
#   'source': 'stsd-fr'},
#  {'texts': ['Cinq chatons mangent dans cinq plats.',
#    'Les chatons mangent de la nourriture sur des plateaux.'],
#   'label': 0.55,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de découper du thon.',
#    'Une femme coupe du poisson cru.'],
#   'label': 0.5599999904632569,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme qui joue de la guitare.',
#    'Une femme se peint les lèvres.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la flûte.', 'Un chien aboie pour une mouche.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un bébé rhinocéros se promène dans son enclos avec sa mère.',
#    'Un bébé rhinocéros suit un rhinocéros adulte.'],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme a utilisé une épée pour trancher une bouteille en plastique.",
#    'Un homme a tranché une bouteille en plastique avec une épée.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Un homme nettoie un poisson sur le comptoir d'une cuisine.",
#    'Un homme joue de la flûte.'],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne est en train de couper des feuilles de coriandre.',
#    'Une femme est en train de couper des feuilles vertes.'],
#   'label': 0.45,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme appuie sur les boutons du micro-ondes.',
#    'Un homme allume le micro-ondes.'],
#   'label': 0.55,
#   'source': 'stsd-fr'},
#  {'texts': ['Une fille monte à cheval.', 'La jeune fille a trotté le cheval.'],
#   'label': 0.9,
#   'source': 'stsd-fr'},
#  {'texts': ["Batman et Robin volent en hélicoptère au-dessus de l'eau.",
#    "Un hélicoptère vole au-dessus de l'eau."],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ["Une femme verse de l'huile dans une poêle à partir d'une bouteille en plastique pendant qu'elle parle.",
#    "Une femme âgée verse de l'huile dans une poêle sur le fourneau."],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de couper des herbes.',
#    'Une femme est en train de couper de la coriandre.'],
#   'label': 0.5599999904632569,
#   'source': 'stsd-fr'},
#  {'texts': ["La dame a mis la brochette de shimp dans l'eau chaude.",
#    "La dame a fait frire la viande panée dans de l'huile chaude."],
#   'label': 0.3200000047683716,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est à cheval.', 'Un homme tire au fusil.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Le garçon joue du piano.', 'Un groupe joue sur scène.'],
#   'label': 0.2665999889373779,
#   'source': 'stsd-fr'},
#  {'texts': ['Le cuisinier pétrit la farine.',
#    'Une femme pétrit la pâte à tortilla.'],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ["Une femme monte à cheval le long d'un périmètre.",
#    'Un chien fait du skateboard.'],
#   'label': 0.12000000476837158,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme met son bébé dans une poubelle.',
#    'La femme fait des trous dans la pomme de terre.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chat se jette sur un trampoline.',
#    'Un homme coupe une tomate en tranches.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme et une femme mangent à une table.',
#    'Un couple prend un repas et discute.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est à cheval.',
#    'Un homme retourne les tables avec colère.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de visser du bois à un mur.',
#    'Un homme fait un massage à une femme.'],
#   'label': 0.04000000059604645,
#   'source': 'stsd-fr'},
#  {'texts': ['Une fille joue de la flûte.',
#    "Une fille joue d'un instrument à vent."],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Un petit bébé joue de la guitare.',
#    'Un garçon est assis sur un lit, chante et joue de la guitare.'],
#   'label': 0.4,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de couper un oignon.',
#    'Un homme fait un tour de cartes.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme et une femme se promènent dans les bois.',
#    "L'homme et la femme marchent."],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Un enfant joue à un jeu informatique.',
#    'Un garçon joue à un jeu sur un ordinateur portable.'],
#   'label': 0.6182000160217285,
#   'source': 'stsd-fr'},
#  {'texts': ["Des hommes sautent dans l'eau depuis un pont.",
#    'Des hommes sautent dans une rivière.'],
#   'label': 0.55,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de peler du poisson.',
#    'Une femme verse un mélange jaune sur une poêle à frire.'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ['Les gens jouent au base-ball.',
#    'Le joueur de cricket a frappé la balle.'],
#   'label': 0.1,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne fait bouillir de la soupe.',
#    'Une femme met des œufs dans une casserole.'],
#   'label': 0.05,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de danser.', 'Un homme casse un bâton.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un danseur de ballet se produit sur scène.',
#    'Le castor est caressé.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme tire un panier.', 'Un homme joue de la guitare.'],
#   'label': 0.1,
#   'source': 'stsd-fr'},
#  {'texts': ['Les éléphants se baignent.', 'Deux femmes chantent.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme a coupé un oignon.", 'Un homme est en train de danser.'],
#   'label': 0.12000000476837158,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme met des cosmétiques sur sa paupière.',
#    'La femme est en train de dessiner au crayon sur un fard à paupières.'],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ["Une femme et un homme sont à bord d'une voiture.",
#    "Une femme conduisant une voiture parle à l'homme assis à côté d'elle."],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ['Une fille danse dans une cage.',
#    "Un oignon est en train d'être haché."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chat est sur un robot.', 'Un homme mange du pain.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['La dame a remué des œufs crus dans le bol.',
#    'Une femme verse des yeux dans un bol.'],
#   'label': 0.2,
#   'source': 'stsd-fr'},
#  {'texts': ["Une vache mange de l'herbe.",
#    "Un chien tire une fille en bas d'une colline."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme a remué la sauce pour le poulet.",
#    "L'homme remue l'huile."],
#   'label': 0.48000001907348633,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme qui saute à la corde', 'Un homme parle.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme épluche une orange.',
#    "Une femme coupe un petit morceau d'écorce de citron."],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["Quelqu'un bat un œuf.", 'Une femme remue des œufs dans un bol.'],
#   'label': 0.5,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme coupe une pomme de terre.',
#    'Une femme joue de la guitare électrique.'],
#   'label': 0.016599999368190767,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de beurrer un morceau de pain.',
#    'Un loris lent suspendu à une corde.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme coupe des légumes.',
#    'Une femme place des brochettes de nourriture sur une cuisinière.'],
#   'label': 0.2,
#   'source': 'stsd-fr'},
#  {'texts': ["La dame a coupé la queue et le corps d'une crevette.",
#    'Une femme est en train de nettoyer une crevette.'],
#   'label': 0.9,
#   'source': 'stsd-fr'},
#  {'texts': ["Un homme joue d'une guitare acoustique.",
#    'Une femme et un chien se promènent ensemble.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne est en train de peler des crevettes.',
#    'Une personne prépare des crevettes.'],
#   'label': 0.7199999809265136,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme coupe des brocolis.',
#    'Une femme est en train de couper des brocolis.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un petit chien couché sur le lit.',
#    'Un petit chien est couché sur un lit.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme coupe une pomme de terre en tranches.",
#    'Un homme coupe une pomme de terre.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme coupe une pomme de terre en tranches.",
#    'Un homme coupe une pomme de terre.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne est en train de peler des crevettes.',
#    'Un homme est en train de peler des crevettes.'],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme met des lunettes de soleil.',
#    'Une femme met des lunettes de soleil.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme coupe une pomme de terre.',
#    'Une femme coupe une carotte.'],
#   'label': 0.5,
#   'source': 'stsd-fr'},
#  {'texts': ['Les femmes courent.', 'Deux femmes se présentent.'],
#   'label': 0.764799976348877,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la harpe.', 'Une femme joue de la guitare.'],
#   'label': 0.3200000047683716,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme plonge dans une piscine.',
#    'Un homme plonge dans une piscine.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme écrase de l'ail.", "Un homme écrase de l'ail."],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de couper une pomme de terre.',
#    'Un homme est en train de couper des carottes.'],
#   'label': 0.475,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme coupe un oignon en tranches.',
#    'Un homme coupe un oignon.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de danser.', 'Un homme chante.'],
#   'label': 0.25,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de courir.', 'Un homme chante.'],
#   'label': 0.25,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme fait une randonnée dans les bois.",
#    'Un homme est en train de suivre dans le bois.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la flûte.', 'Un homme joue de la guitare.'],
#   'label': 0.43340001106262205,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est à vélo.', 'Une femme monte à cheval.'],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme joue de la guitare.',
#    'Une personne joue de la guitare.'],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de manger une pizza.',
#    'Un homme mange un aliment.'],
#   'label': 0.7199999809265136,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.', 'Un homme joue de la guitare.'],
#   'label': 0.971399974822998,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme est en train de beurrer le pain.",
#    "L'homme est en train de remuer le riz."],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme frappe un homme.', 'Une femme prend un bain.'],
#   'label': 0.04000000059604645,
#   'source': 'stsd-fr'},
#  {'texts': ['Trois hommes dansent.', 'Les femmes dansent.'],
#   'label': 0.25999999046325684,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme parle.', 'Un homme est en train de danser.'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de danser.', 'Un homme parle.'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne peigne un poil de chat.',
#    'Une personne est en train de brosser un chat.'],
#   'label': 0.8800000190734864,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la batterie.', 'Un homme joue de la guitare.'],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est en train de peler une banane.',
#    'Une femme épluche une pomme de terre.'],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ['Un garçon monte à cheval.', 'Un singe est dans un bus.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Le chiot a essayé de sortir de la baignoire.',
#    "Un chiot essaie de sortir d'une baignoire."],
#   'label': 0.8800000190734864,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme épluche un oignon.',
#    'La femme est en train de couper des oignons verts.'],
#   'label': 0.65,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne est en train de mélanger un pot de riz.',
#    "Une personne est en train d'éplucher une pomme de terre."],
#   'label': 0.1555999994277954,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.', 'La fille joue de la guitare.'],
#   'label': 0.45,
#   'source': 'stsd-fr'},
#  {'texts': ["Un lionceau essaie d'escalader une clôture.",
#    'Un lion tente de franchir un mur.'],
#   'label': 0.55,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme parle sur un téléphone portable.',
#    'Un type parle dans un micro.'],
#   'label': 0.4,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.',
#    'Un homme est en train de nettoyer un cd.'],
#   'label': 0.1666000008583069,
#   'source': 'stsd-fr'},
#  {'texts': ["Quelqu'un verse du bouillon de poulet dans une marmite.",
#    "L'homme verse du bouillon dans la marmite."],
#   'label': 0.75,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de couper un oignon.',
#    "Une femme coupe de l'ail avec un couteau."],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme serre la main d'autres hommes.",
#    "Un homme serre la main d'un autre homme."],
#   'label': 0.8666000366210938,
#   'source': 'stsd-fr'},
#  {'texts': ["Une cible est touchée par des tirs d'armes à feu.",
#    'La cible était atteinte par des balles.'],
#   'label': 0.8428000450134278,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme se maquille.', 'Un homme joue de la guitare.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme coupe un gros poivron.',
#    'Une personne est en train de couper un poivron vert.'],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme met du fromage sur une pizza.',
#    'Un homme saupoudre du fromage râpé sur une pizza.'],
#   'label': 0.8399999618530274,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme regarde une feuille.',
#    'Un homme est en train de couper un légume.'],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne choisit un dragon de komodo et le met dans une boîte.',
#    'Une personne place un bébé dragon de Komodo dans un récipient.'],
#   'label': 0.8399999618530274,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne fait tomber une caméra sur un accélérateur.',
#    'Un homme jette un sac dans un escalier roulant.'],
#   'label': 0.55,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme joue des claviers.", 'Un homme joue de la guitare.'],
#   'label': 0.4400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme applique un fard à paupières.',
#    'Une femme est en train de laver un bol.'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme joue de la flûte.', 'Un homme joue du clavier.'],
#   'label': 0.2,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est monté sur un cheval.',
#    'Une femme monte un éléphant.'],
#   'label': 0.3065999984741211,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la flûte.', 'Un homme est en train de danser.'],
#   'label': 0.04000000059604645,
#   'source': 'stsd-fr'},
#  {'texts': ['Un tigre se promène dans sa cage.',
#    'Un tigre se promène sans but.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ["Une personne verse de l'huile de cuisson dans une marmite.",
#    "Une personne verse de l'huile d'olive dans un pot sur le feu."],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme coupe une pomme de terre.',
#    'Une femme monte à cheval.'],
#   'label': 0.15,
#   'source': 'stsd-fr'},
#  {'texts': ['Un perroquet parle.', 'Un perroquet parle dans un microphone.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme chante dans un micro.', 'Un homme danse sous la pluie.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ["Une femme fait de l'exercice.", 'Une femme soulève des poids.'],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ["Un enfant court dans les vagues de l'océan et en sort.",
#    "Un jeune garçon court vers et depuis les vagues de l'océan."],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue du piano.', 'Un homme joue de la flûte en bois.'],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ['Un type est à cheval.',
#    'Un homme monte à cheval dans le désert.'],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chien vole de la nourriture dans un réfrigérateur.',
#    'Le chien a pris quelque chose dans le réfrigérateur.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne utilise un chalumeau sur deux caméras.',
#    'Une personne brûle des caméras.'],
#   'label': 0.4665999889373779,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme met un couteau dans un étau.',
#    'Un homme monte dans une voiture dans un garage.'],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme fait cuire de la viande.', 'Un homme parle.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Un chiot essaie de sortir de l'évier.",
#    'Le chiot a essayé de sortir de la baignoire.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne plie un morceau de papier carré.',
#    'Une personne plie un morceau de papier.'],
#   'label': 0.75,
#   'source': 'stsd-fr'},
#  {'texts': ['Le garçon joue du piano.',
#    "La femme verse de l'huile dans la casserole."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme coupe une pomme de terre.',
#    "Une femme est en train d'escalader une paroi rocheuse."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme nourrit un bébé.',
#    "Un homme ajoute de l'eau dans une casserole."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare.', 'Une femme monte à cheval.'],
#   'label': 0.1,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme est en train de mélanger des œufs.',
#    'La femme est en train de manger.'],
#   'label': 0.1,
#   'source': 'stsd-fr'},
#  {'texts': ["Un homme est à bord d'un bateau.",
#    "Un homme est en train d'attacher la machine."],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme sert un gâteau.', 'Un homme assaisonnant des cailles.'],
#   'label': 0.15,
#   'source': 'stsd-fr'},
#  {'texts': ["Quelqu'un est en train de faire une super carotte.",
#    'Une femme râpe une orange.'],
#   'label': 0.5,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme est debout sur un toit et joue du violon.',
#    'Un homme est sur un toit en train de danser.'],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Un singe fait du karaté en frappant une personne.',
#    'Un singe pratique les arts martiaux.'],
#   'label': 0.5,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme secoue un couteau.', 'Un homme porte une femme.'],
#   'label': 0.1,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme se brosse les pieds.',
#    'Une femme est en train de couper un oignon.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme enlève la peau de certaines viandes.',
#    'Une femme coupe une tomate.'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme remue les ingrédients dans un bol.',
#    'Un homme bat deux œufs dans un bol avec une fourchette.'],
#   'label': 0.55,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme se détend dans une baignoire.',
#    'Une femme poignarde une pomme de terre avec une fourchette.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ["Une femme ajoute de l'huile sur des poissons.",
#    'La femme est en train de couper des pommes de terre.'],
#   'label': 0.12000000476837158,
#   'source': 'stsd-fr'},
#  {'texts': ["Une femme est en train d'écrire quelque chose.",
#    'Une femme est en train de couper des oignons verts.'],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ['Un bébé mange sa nourriture.',
#    'Un bébé est nourri de petits pois.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme coupe une carotte avec une machine.',
#    'Un homme est debout sous la pluie.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare et chante sur une scène.',
#    'Un homme joue de la guitare électrique.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Un garçon joue du piano.',
#    'Un homme chante et joue de la guitare.'],
#   'label': 0.25,
#   'source': 'stsd-fr'},
#  {'texts': ['La personne allume un feu.', 'Une personne fait du feu.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme monte à cheval sur la plage.',
#    'Une femme est en train de laver un bol.'],
#   'label': 0.04000000059604645,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne est en train de couper une herbe.',
#    'Un homme est en train de hacher finement une substance verte.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ["Une femme recueille l'eau du robinet dans une tasse.",
#    "Un garçon remplit un pichet d'eau."],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ['Une personne est en train de fouetter des œufs dans un bol.',
#    "Une femme bat deux œufs dans un bol à l'aide d'un fouet en fil de fer."],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Le chien ne savait pas comment faire sortir un bâton de la porte du chien.',
#    'Un chien essaie de passer sa porte.'],
#   'label': 0.55,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme mélange des œufs dans le bol.',
#    'Un homme fait des pompes.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['La dame a fait quelques tranches sur les crevettes.',
#    'Un chef coupe une crevette.'],
#   'label': 0.5599999904632569,
#   'source': 'stsd-fr'},
#  {'texts': ["Quelqu'un est en train de mélanger un liquide.",
#    'Un homme joue de la guitare.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme coupe un gros poivron.',
#    "Un homme joue d'un instrument."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'animal aux grands yeux est en train de manger.",
#    'Un loris lent est en train de manger.'],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Un bébé rampe joyeusement.',
#    'Un chat marche sur un plancher de bois dur.'],
#   'label': 0.020000000298023225,
#   'source': 'stsd-fr'},
#  {'texts': ['Un club de tigres joue avec une balle.',
#    'Une personne coupe des crevettes avec un couteau.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme coupe des fruits.', 'Deux femmes coupent des citrons.'],
#   'label': 0.4,
#   'source': 'stsd-fr'},
#  {'texts': ['Le drapeau bougeait dans les airs.', 'Un drapeau est agité.'],
#   'label': 0.75,
#   'source': 'stsd-fr'},
#  {'texts': ['Le bébé riait dans son siège auto.', 'Un bébé rit.'],
#   'label': 0.6199999809265136,
#   'source': 'stsd-fr'},
#  {'texts': ["Un chien frappe un garçon dans l'eau à deux reprises.",
#    "Un chien pousse un bambin dans une flaque d'eau de pluie."],
#   'label': 0.5383999824523926,
#   'source': 'stsd-fr'},
#  {'texts': ["L'oiseau prend un bain sous le robinet.",
#    'Un oiseau se baigne dans un évier.'],
#   'label': 0.8857999801635742,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue de la guitare et chante.',
#    'Un homme chante et joue de la guitare.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Les femmes se serrent les unes contre les autres et dansent ensemble.',
#    'Deux hommes jouent au tennis de table.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme essaie de nourrir le serpent avec une souris.",
#    'Un homme travaille sur son ordinateur portable.'],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ['Un tigre joue avec son dresseur.', 'Un tigre attaque un homme.'],
#   'label': 0.2665999889373779,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chat joue avec une pastèque sur un plancher.',
#    "Un homme verse de l'huile dans une casserole."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Un chat récupère un objet dans un plat d'eau.",
#    "Le chat a essayé de manger l'épi de maïs."],
#   'label': 0.12000000476837158,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chef coupe une carotte.',
#    'Une personne est en train de faire un dessin.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme ajoute des champignons et du liquide dans une marmite.',
#    'Un jeune homme joue de la guitare.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme joue passionnément de la guitare devant un public.',
#    'Une femme épluche une pomme de terre.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Quelqu'un a dessiné le visage de Washington sur le dollar.",
#    "Une personne tire sur un billet d'un dollar."],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ['La fille coupe un oignon.',
#    'Une femme coupe un oignon en petits morceaux.'],
#   'label': 0.4400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ["L'homme vise un fusil.",
#    'Un garçon joue sur un téléphone jouet.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Un chat debout sur les branches d'un arbre.",
#    "Un chat noir et blanc est haut sur les branches d'un arbre."],
#   'label': 0.7199999809265136,
#   'source': 'stsd-fr'},
#  {'texts': ["L'agneau regarde la caméra.",
#    "Un petit oiseau debout sur un rondin au bord de l'eau."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Un taureau debout dans le champ.',
#    'Un cheval brun se tient dans un champ vert luxuriant.'],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ["Les vaches noires et blanches s'arrêtent devant la porte.",
#    'Une vache noire et une vache brune se tiennent dans une plaine devant un arbre déraciné.'],
#   'label': 0.4400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Un groupe de quatre personnes en train de dîner en mangeant un gâteau.',
#    "Quatre personnes mangeant un dessert autour d'une table."],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["Un groupe de personnes mange à une table à l'extérieur.",
#    "Un groupe de personnes âgées pose autour d'une table à manger."],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Homme âgé portant un béret avec des montagnes en arrière-plan.',
#    'Un mouton dans la brume matinale avec des arbres en arrière-plan.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ["Les vaches se nourrissent dans l'auge.",
#    "Les vaches brunes et blanches mangent dans l'auge."],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ["Un petit oiseau rouge et gris perché parmi les branches nues d'un arbre.",
#    'Un oiseau rouge et brun est perché sur les branches.'],
#   'label': 0.45,
#   'source': 'stsd-fr'},
#  {'texts': ['Une salle à manger de couleur noire et boisée dans un petit appartement.',
#    'Table noire et marron dans le décor du salon.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Un sac de coton devant un canapé.',
#    "Chat Calico assis sur le pas d'une porte."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Deux chevaux se tiennent dans un champ avec des arbres en arrière-plan.',
#    "Un oiseau noir et blanc sur un plan d'eau avec de l'herbe en arrière-plan."],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Bus rouge à deux étages descendant une rue.',
#    'Un bus rouge à deux étages circulant dans la rue.'],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["L'agneau regarde la caméra.", 'Un chat qui regarde la caméra.'],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ['Un bus rouge à deux étages dans une rue très fréquentée.',
#    'Un bus à deux étages dans une rue de la ville.'],
#   'label': 0.8399999618530274,
#   'source': 'stsd-fr'},
#  {'texts': ['Un jockey à cheval dans un enclos.',
#    'Un jockey monte à cheval au galop.'],
#   'label': 0.7199999809265136,
#   'source': 'stsd-fr'},
#  {'texts': ["Les pis d'une vache laitière qui se trouve dans un pâturage près d'un grand bâtiment.",
#    "La vache noire et brune est debout sur l'herbe verte."],
#   'label': 0.4,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme posant devant un pilier avec un signe U2.',
#    'une femme est debout près d\'un pilier où est écrit "u2".'],
#   'label': 0.8399999618530274,
#   'source': 'stsd-fr'},
#  {'texts': ["Une Asiatique et une femme à lunettes souriant le pouce en l'air.",
#    "Deux femmes posent pour la caméra et donnent le signe des pouces en l'air."],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ['Un train noir descend les rails.',
#    'Un train essentiellement noir sur une voie.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Le chien brun repose sa tête sur un oreiller blanc.',
#    'Un chien bronzé est allongé sur un canapé et a la tête sur un oreiller blanc.'],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ['La vache noire et brune regarde la caméra.',
#    'Le taureau en noir et blanc regarde la caméra.'],
#   'label': 0.7199999809265136,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme souriante tenant un petit bébé dans ses bras.',
#    'Deux femmes souriantes tenant un bébé.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ['Deux avions dans le ciel.', 'Un avion dans le ciel.'],
#   'label': 0.48000001907348633,
#   'source': 'stsd-fr'},
#  {'texts': ['Un train de charbon qui circule sur les rails.',
#    'Un vieux train reste au ralenti sur les rails.'],
#   'label': 0.4,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chat qui regarde la caméra.',
#    'Un chat gris, noir et blanc qui regarde la caméra.'],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ["Les titres de l'actualité mondiale affichés sur un grand écran.",
#    'Un homme habillé pour une course se détend.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Deux femmes posent avec un bébé.',
#    'Deux femmes souriantes tenant un bébé.'],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ['Un avion rouge et blanc qui vole par une journée ensoleillée.',
#    'Un avion rouge et blanc qui vole dans les airs.'],
#   'label': 0.8399999618530274,
#   'source': 'stsd-fr'},
#  {'texts': ["Une photo en noir et blanc d'une ancienne gare.",
#    "Une photo en noir et blanc d'un chat assis sur un canapé."],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ['Une bicyclette devant des ruines.',
#    'Une bicyclette rose se trouve devant un bâtiment.'],
#   'label': 0.4400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Bus rouge à deux étages sur le côté de la rue.',
#    'Un bus rouge à deux étages dans une rue très fréquentée.'],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Un bus circule sur une route très fréquentée.',
#    'Un bus vert circule sur une route.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ["Un couple d'Asiatiques âgés pose avec un bébé qui baille à table.",
#    'Un couple asiatique âgé pose avec un nouveau-né à la table du dîner.'],
#   'label': 0.8800000190734864,
#   'source': 'stsd-fr'},
#  {'texts': ["Des canards bruns et blancs marchant sur l'herbe verte.",
#    'Un avion rouge et blanc qui vole par une journée ensoleillée.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Les gens conduisent des cyclomoteurs dans un cadre urbain.',
#    'Des gens qui montent à cheval dans une zone clôturée.'],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ['Grand moteur de locomotive en argent dans un hangar.',
#    'Le train argenté est garé dans une gare.'],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Deux personnes assises sur une grande moto.',
#    'Deux aigles assis sur une longue branche.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ["Une femme peu vêtue se tient à côté d'une voiture.",
#    "Un oiseau jaune et orange se tient sur le côté d'une cage."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Plusieurs téléviseurs sont posés par terre et empilés les uns sur les autres.',
#    'Trois téléviseurs, au sol, les deux autres sur une boîte.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ["Des moutons paissent dans un champ herbeux près d'un peuplement d'arbres.",
#    "Des moutons paissent dans le champ devant une rangée d'arbres."],
#   'label': 0.9199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Le petit chien protège son maître.',
#    "Le dos du panneau stop est orné d'autocollants."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Des enfants regardant un mouton.',
#    "Enfant trayant une vache à l'extérieur."],
#   'label': 0.12000000476837158,
#   'source': 'stsd-fr'},
#  {'texts': ["Une photo en noir et blanc d'une causeuse.",
#    "Une photo en noir et blanc d'une ancienne gare."],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ["le dos d'un panneau stop avec de nombreux autocollants.",
#    "Le dos d'un panneau avec des autocollants."],
#   'label': 0.7599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Salle de séjour ou de repos avec télévision grand écran.',
#    'Salle de séjour avec meubles de bronzage et télévision à écran plat.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Deux femmes assises sur des chaises de jardin.',
#    'Deux femmes sont assises dans un café.'],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Un bus rouge à deux étages qui roule sur la route.',
#    'Un bus rouge à deux étages descendant une rue.'],
#   'label': 1.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'oiseau noir est assis sur le sol.",
#    "Le dos d'un cochon sous un arbre avec une vache en arrière-plan."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Un avion de Das Air Cargo s'assoit sur la piste.",
#    'Un avion de ligne garé sur une piste.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chat dort sur un drap violet.',
#    'Un chat noir et blanc dort sur une couverture violette.'],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ["Gros plan d'un chat sur un canapé crème.",
#    'Gros plan sur un cheval.'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ['Une cuisine avec des armoires en bois et une table à manger.',
#    'Une cuisine avec des armoires et des meubles en bois.'],
#   'label': 0.8800000190734864,
#   'source': 'stsd-fr'},
#  {'texts': ["Une moto est garée près d'un mur recouvert d'un graffiti représentant un paysage urbain.",
#    "Le soir, une moto est garée près d'une fresque murale d'une ville."],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ["Deux garçons sont assis face à face à une table et l'un d'eux montre l'autre.",
#    "Deux personnes sont assises face à face à une table, l'une montrant l'autre."],
#   'label': 0.8800000190734864,
#   'source': 'stsd-fr'},
#  {'texts': ["Deux chiens blancs nagent dans l'eau.",
#    "Les oiseaux nagent dans l'eau."],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ["Grand bateau de croisière blanc flottant sur l'eau.",
#    "Grand bateau de croisière flottant sur l'eau."],
#   'label': 0.9199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Deux pygargues à tête blanche perchés sur une branche.',
#    'Deux aigles sont perchés sur une branche.'],
#   'label': 0.8399999618530274,
#   'source': 'stsd-fr'},
#  {'texts': ["Un sac à dos à côté d'un train.",
#    'Une réunion sociale de personnes dans un restaurant.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["L'oiseau est assis sur la branche.",
#    'Un oiseau rouge et brun est perché sur les branches.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Un groupe de personnes posant avec des chapeaux de fourrure.',
#    'Un groupe de cyclistes en vert et blanc sous le regard des spectateurs.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Chat domestique noir couché sur une table marron.',
#    'Un chat gris allongé sur une table à manger.'],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ['Quatre enfants regardent les animaux de la grange.',
#    'Des enfants regardant un mouton.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ['Un chat noir et blanc qui joue avec un panier de laine.',
#    'Un chat noir et blanc couché sur une couverture.'],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["Deux hommes sur un bateau qui flotte sur l'eau.",
#    "Un yacht en bois sur l'océan."],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['Un homme qui fait un wheelie sur un vélo de montagne.',
#    'Une femme posant devant un pilier avec un signe U2.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Une femme à cheval.', 'La femme monte sur le cheval brun.'],
#   'label': 0.7599999904632568,
# ...
#   'source': 'stsd-fr'},
#  {'texts': ['Cette idée existe depuis le début du mythe et de la narration.',
#    'La science des super-héros pourrait nous éclairer sur ce sujet.'],
#   'label': 0.04000000059604645,
#   'source': 'stsd-fr'},
#  {'texts': ["Est-il possible qu'un match soit à égalité même après avoir appliqué la méthode D/L ?",
#    "Oui, il est possible qu'un match soit à égalité après application de la méthode D/L."],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ['Oui, une équipe peut utiliser le même joueur pour le bowling et la batte dans un super over.',
#    'Aucune règle ne détermine quels joueurs peuvent être sélectionnés pour jouer au bowling ou au bâton dans le Super Over.'],
#   'label': 0.8399999618530274,
#   'source': 'stsd-fr'},
#  {'texts': ["Il s'agit simplement du nombre de boules jouées divisé par le nombre de guichets pris.",
#    "Le taux d'abattage du bowling est défini pour un joueur de bowling comme le nombre moyen de boules jouées par guichet pris."],
#   'label': 0.8800000190734864,
#   'source': 'stsd-fr'},
#  {'texts': ["Oui, absolument - le joueur qui reçoit doit laisser la balle rebondir avant de renvoyer le service - ou n'importe quel tir, en fait.",
#    'Oui, le receveur doit attendre que la balle touche son aire de jeu, sinon elle compte comme étant obstruée.'],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ["Nous n'avons utilisé Fartlek que pour mesurer la forme physique, et pour nous amuser un peu.",
#    "Fartlek n'est pas plus efficace que n'importe quel entraînement par intervalles - juste plus amusant !"],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Si le nombre de quatre frappés par deux équipes est également égal, les deux équipes obtiendront 1 point chacune.',
#    "C'est la règle si les points marqués par deux équipes en Super Over sont égaux..."],
#   'label': 0.12000000476837158,
#   'source': 'stsd-fr'},
#  {'texts': ['Les femmes sont apparues pour la première fois aux Jeux olympiques modernes en croquet aux Jeux olympiques de 1900.',
#    'En 1900, les deuxièmes Jeux olympiques modernes, 22 femmes ont participé à 5 épreuves : tennis, voile, croquet, équitation et golf.'],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ["Il est difficile de parler au nom d'une équipe, de savoir quelle est sa stratégie dans un projet.",
#    'La rédaction a considérablement changé avec la nouvelle convention collective.'],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Pour jouer au golf, la première chose dont vous avez besoin est un jeu de clubs.',
#    'Ayant moi-même pratiqué ce sport assez récemment, je ressens votre malaise.'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ["Oui, le facteur de rosée (humidité dans l'environnement) peut changer la direction d'une allumette.",
#    "Un autre inconvénient du facteur de rosée est qu'il rend difficile l'atteinte des limites."],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ["La lecture de votre billet m'a fait penser à mes jeunes années !",
#    "Je dirais qu'il faut se distraire de la vue d'ensemble."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Il n'y a AUCUNE bonne raison pour ne pas mettre en place des jeux vidéo dans le football professionnel.",
#    "Il y a un autre problème avec l'application de rediffusions instantanées qui ne se limitent pas à interrompre le déroulement du jeu."],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ["En gros, la règle est que vous devez jouer la balle, et non l'homme, jusqu'à ce que quelqu'un attrape la balle.",
#    'Il est assez simple à comprendre, un peu plus difficile à arbitrer.'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ["Au plus haut niveau, un régulateur de rythme permet de s'assurer qu'ils respectent exactement leur plan de jeu pour la course.",
#    "D'après mon expérience personnelle, j'ai trouvé qu'un pace setter était incroyablement utile."],
#   'label': 0.5599999904632569,
#   'source': 'stsd-fr'},
#  {'texts': ['Je peux penser à trois facteurs clés qui sont des conjectures assez logiques.',
#    "Il y a eu un certain nombre d'études dans le domaine du football/soccer sur l'avantage du terrain à domicile."],
#   'label': 0.04000000059604645,
#   'source': 'stsd-fr'},
#  {'texts': ["Le mouvement de la boule en l'air est appelé swing bowling.",
#    'Ces deux styles de bowling sont pratiqués par des joueurs qui sont des joueurs de vitesse moyenne ou rapide.'],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["En fait, il est beaucoup plus facile de compter celui qui n'est PAS sur le même continent.",
#    "C'est également la stratégie recommandée pour les marathons, si vous voulez gagner du temps."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Le ballon rouge sous un projecteur jaune prend une couleur brunâtre qui ressemble beaucoup à la couleur du terrain.',
#    'Je suis aussi un nageur amateur, mais dans le cadre de mon entraînement au triathlon.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Non, il n'y a pas de critères spécifiques pour décerner le prix de l'homme du match.",
#    "Selon les règles, l'attribution des MoM est décidée par le panel de départ."],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ["Je n'en connais pas les détails, mais il me semble me souvenir de ce scénario d'il y a de nombreuses années.",
#    "Les lois du cricket stipulent que vous pouvez déclarer n'importe quelle manche, quelle que soit la durée convenue."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Conformément à l\'article 22 du "Règlement sur l\'équipement" de la FIFA, seul le gardien de but est autorisé à porter une casquette.',
#    "Bien que le port du casque soit autorisé, il n'est conseillé qu'au gardien de but."],
#   'label': 0.48000001907348633,
#   'source': 'stsd-fr'},
#  {'texts': ["Heureux d'apprendre que vous avez commencé à jouer au hockey, c'est un sport formidable !",
#    'La règle générale est de patiner toutes les 5-6 heures.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Je préfère courir la deuxième mi-temps 1 à 2 minutes plus vite que la première.',
#    "J'opterais certainement pour une première mi-temps un peu plus lente."],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ["C'est par hasard qu'elle a affronté Li Na au premier tour - et non parce qu'elle est classée numéro 127.",
#    "C'était trop long pour un commentaire, alors je le publie en tant que réponse CW."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["La plupart du temps, vous pouvez faire votre demande dans n'importe quel consulat américain.",
#    'En général, vous êtes censé faire votre demande au consulat américain de votre lieu de résidence.'],
#   'label': 0.7199999809265136,
#   'source': 'stsd-fr'},
#  {'texts': ['Il y a une compagnie aérienne, Spirit Airlines, qui essaie de copier Ryanair avec des billets super bon marché et un service agressif de mauvaise qualité.',
#    'Il existe quelques compagnies aériennes qui proposent des vols à des tarifs plus bas.'],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["Je vous suggère de trouver une banque dans votre pays et d'envisager d'ouvrir un compte bancaire libellé en euros auprès d'elle.",
#    "Je ne suis pas sûr que vous puissiez ouvrir un compte bancaire en France si vous n'êtes pas résident."],
#   'label': 0.3200000047683716,
#   'source': 'stsd-fr'},
#  {'texts': ['Si je me souviens bien, à Genève au moins, il y a des marchés en plein air sur une base hebdomadaire.',
#    'Cette page répertorie tous les grands marchés de Noël en Suisse.'],
#   'label': 0.4,
#   'source': 'stsd-fr'},
#  {'texts': ["Mon expérience est qu'un taxi normal est toujours moins cher.",
#    "Lorsque vous utilisez un taxi régulier, assurez-vous qu'il est assuré par une société réputée ou que vous vous êtes mis d'accord sur le tarif à l'avance."],
#   'label': 0.4,
#   'source': 'stsd-fr'},
#  {'texts': ["J'avais un problème similaire mais dans une situation qui semblait plus simple.",
#    'En fait, je suis sur le point de faire la même chose lors de mon transfert à Londres Heathrow.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Un arrêt technique est au profit de l'AVION.",
#    "En général, il s'agit d'un arrêt de ravitaillement en carburant, et vous restez assis dans l'avion."],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Kyoto, du moins, le fait, comme décrit ici : JR Station de Kyoto.',
#    'La plupart des gares japonaises sont équipées de casiers à monnaie.'],
#   'label': 0.0800000011920929,
#   'source': 'stsd-fr'},
#  {'texts': ['Il y a une réponse geek à cela, et une réponse pratique à cela.',
#    "Il est assez ridicule que j'aie vu des compagnies aériennes demander que ces appareils soient parfois éteints."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["J'ai visité le Pérou en août, en partant de Lima et en faisant une tournée de trois semaines.",
#    "Cusco : Haut : 70F Bas : 40F C'est juste avant la saison des pluies (déc-mars) et les foules sont généralement moins nombreuses."],
#   'label': 0.04000000059604645,
#   'source': 'stsd-fr'},
#  {'texts': ["En général, presque partout où je vais, je trouve qu'il est plus facile de retirer de l'argent au distributeur.",
#    'Il y a beaucoup de distributeurs automatiques de billets et de bureaux de change dans toute la ville, en particulier dans le centre ville.'],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ['La plus évidente est la plus ancienne marche de longue distance en Écosse : Le West Highland Way.',
#    'Regardez ça : http://www.capewrathtrail.co.uk/ Vous pourriez le faire par étapes.'],
#   'label': 0.3200000047683716,
#   'source': 'stsd-fr'},
#  {'texts': ['La réponse dépendra en grande partie du pays dans lequel vous vous rendez.',
#    'Ayant toujours voyagé avec beaucoup de médicaments sur ordonnance, je le déclare toujours.'],
#   'label': 0.2,
#   'source': 'stsd-fr'},
#  {'texts': ["Il y a des trains qui passent par Knin, ce qui signifie un grand détour par l'intérieur des terres (il n'y a tout simplement pas de ligne côtière).",
#    "Comme d'autres l'ont dit, si vous voulez vous rendre à Split, la meilleure offre de transport public est le bus."],
#   'label': 0.12000000476837158,
#   'source': 'stsd-fr'},
#  {'texts': ['Aller sur un cargo compterait-il comme une tournée ?',
#    'Ozbus propose une tournée de 29 semaines en Amérique du Sud, avec départ et arrivée à Quito.'],
#   'label': 0.2,
#   'source': 'stsd-fr'},
#  {'texts': ["L'anglais fonctionne partout avec les gens qui achètent et vendent des choses et dans le secteur de l'hospitalité et du tourisme.",
#    "J'ai voyagé dans le Maharashtra (y compris à Mumbai) et dans l'Andhra Pradesh et je n'ai eu aucun problème à me débrouiller en anglais."],
#   'label': 0.5599999904632569,
#   'source': 'stsd-fr'},
#  {'texts': ["Je pense que le double objectif a beaucoup à voir avec le but de l'antagoniste.",
#    'Je pense que cela va dépendre des raisons.'],
#   'label': 0.5199999809265137,
#   'source': 'stsd-fr'},
#  {'texts': ['Il n\'y a rien de mal à l\'expression "service d\'échantillonnage simple".',
#    'Le changement minimal nécessaire pour éviter toute allitération déconcertante consiste à l\'appeler simplement "service d\'exemple simple".'],
#   'label': 0.6800000190734863,
#   'source': 'stsd-fr'},
#  {'texts': ["J'ai lancé mon propre outil car je n'aimais pas yWriter et Storybook.",
#    "J'ai essayé beaucoup des choses mentionnées ci-dessus, mais elles n'ont jamais vraiment fonctionné pour moi."],
#   'label': 0.3200000047683716,
#   'source': 'stsd-fr'},
#  {'texts': ["Oui, c'est bien, car cela vous permet de mettre l'accent sur certaines choses, que vous voulez que les lecteurs remarquent.",
#    "Je pense que c'est parfaitement acceptable et que cela souligne bien votre point de vue."],
#   'label': 0.8,
#   'source': 'stsd-fr'},
#  {'texts': ["En ce qui concerne la fiction, je n'ai guère de preuves de la publication de blogs sous forme imprimée et/ou de livres électroniques.",
#    "Pour répondre à votre question, oui, je pense que bloguer votre fiction va nuire à vos tentatives d'être publié traditionnellement plus tard."],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["The War God's Own de David Weber comporte de longues scènes de voyage qu'il réussit assez bien.",
#    "Une chose qui devrait être utilisée comme assaisonnement dans les contes de l'Odyssée est l'idée de la fausse destination."],
#   'label': 0.04000000059604645,
#   'source': 'stsd-fr'},
#  {'texts': ['Il faut définir le problème avant de tenter de le résoudre.',
#    'Chaque fois que je commence à lire les mêmes lignes encore et encore, je me mets à écumer.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ['Votre inquiétude est justifiée ; le lecteur pourrait en être frustré.',
#    "Je ne crois pas que le fait de ne pas connaître le nom d'un personnage puisse prêter à confusion, à moins que vous ne le fassiez."],
#   'label': 0.27999999523162844,
#   'source': 'stsd-fr'},
#  {'texts': ["Non, il n'est pas nécessaire d'avoir suivi des cours ou obtenu un diplôme dans votre région.",
#    "J'ai fait pas mal de rédaction technique pour les systèmes d'information sur les soins de santé."],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["Une chose que vous semblez oublier concernant les mythes, c'est qu'il s'agit d'histoires extrêmement répandues.",
#    'J\'ai remarqué que vous avez dit que les "critiques de cinéma" apprécient les références mythologiques dans un film, mais le public, lui, les apprécie-t-il ?'],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ["Nous venons d'aborder cette question récemment, et l'excellente réponse suggérée était les guillemets.",
#    'guillemets, comme le suggère Lauren Ipsum, est une bonne option.'],
#   'label': 0.7199999809265136,
#   'source': 'stsd-fr'},
#  {'texts': ['Les méchants que je déteste absolument sont égoïstes et égoïstes, mais ce sont aussi des lâches.',
#    "Un méchant que vous voulez abattre est, au fond, quelqu'un qui ne se soucie pas de la souffrance des autres."],
#   'label': 0.6,
#   'source': 'stsd-fr'},
#  {'texts': ["Vous pouvez écrire le livre de la manière que vous voulez, à condition qu'il vous convienne.",
#    "Séquence a seulement dans l'écriture (parfois vous devez revenir en arrière et réviser) option que le non écrivain a est."],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ['Oui, les dialogues ennuyeux doivent être complètement supprimés (ou transformés en dialogues intéressants).',
#    "Je suis d'accord avec la réponse de Lauren : Dans toute histoire, il faut des hauts et des bas."],
#   'label': 0.3599999904632568,
#   'source': 'stsd-fr'},
#  {'texts': ["La réponse à votre question est la suivante : cela dépend de la façon dont l'écrivain travaille.",
#    "Au début, j'ai pensé que c'était une question un peu délicate."],
#   'label': 0.1600000023841858,
#   'source': 'stsd-fr'},
#  {'texts': ["Webster's New World Rhyming Dictionary : Clement Wood's Updated C'est le dictionnaire de rimes que j'utilise en premier.",
#    "http://www.rhymezone.com/ Il vous suffit de taper un mot, puis de sélectionner l'un des éléments suivants."],
#   'label': 0.24000000953674316,
#   'source': 'stsd-fr'},
#  {'texts': ["N'oubliez pas que vous pouvez facilement jurer sans jurer.",
#    'Je pense que les commentaires de Stephen King sont utiles à cet égard.'],
#   'label': 0.0,
#   'source': 'stsd-fr'},
#  {'texts': ["En ces temps de recherche sur Google, il est difficile de ne pas trouver la source d'une citation.",
#    "Je suis d'accord avec Kate Sherwood, vous devriez pouvoir attribuer la plupart des citations de nos jours par simple vérification des faits."],
#   'label': 0.6400000095367432,
#   'source': 'stsd-fr'},
#  {'texts': ["J'ai fait une grande partie de mon travail de description et de pré-écriture dans Workflowy.",
#    'Ai-je encore le droit de battre le tambour pour Scrivener ?'],
#   'label': 0.04000000059604645,
#   'source': 'stsd-fr'},
#  ...]
